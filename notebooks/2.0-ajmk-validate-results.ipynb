# %%
import pandas as pd

# %%
python_converted = pd.read_csv("/Users/alexanderkell/Documents/SGI/Projects/17-ClicSAND/data/processed/output.csv")
python_converted.head(10134)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#              Variable Dim1    Dim2    Dim3 Dim4    Dim5  Dim6  Dim7  Dim8  \
# 0         NewCapacity  RE1  MINCOA    2021  NaN     NaN   NaN   NaN   NaN
# 1         NewCapacity  RE1  MINCOA    2022  NaN     NaN   NaN   NaN   NaN
# 2         NewCapacity  RE1  MINCOA    2023  NaN     NaN   NaN   NaN   NaN
# 3         NewCapacity  RE1  MINCOA    2024  NaN     NaN   NaN   NaN   NaN
# 4         NewCapacity  RE1  MINCOA    2025  NaN     NaN   NaN   NaN   NaN
# ...               ...  ...     ...     ...  ...     ...   ...   ...   ...
# 10129  RateOfActivity  RE1    S120  PWRCOA  1.0  2048.0   NaN   NaN   NaN
# 10130  RateOfActivity  RE1    S121  PWRCOA  1.0  2048.0   NaN   NaN   NaN
# ...

# %%
access_converted = pd.read_csv("/Users/alexanderkell/Documents/SGI/Projects/17-ClicSAND/data/raw/access_output/Results_Database/FinalResultsTable.csv")
access_converted
# Out:
#                        Variable    Dim1    Dim2  Dim3  Dim4  Dim5  Dim6  Dim7  \
# 0                   NewCapacity  MINCOA    2021   NaN   NaN   NaN   NaN   NaN
# 1                   NewCapacity  MINCOA    2022   NaN   NaN   NaN   NaN   NaN
# 2                   NewCapacity  MINCOA    2023   NaN   NaN   NaN   NaN   NaN
# 3                   NewCapacity  MINCOA    2024   NaN   NaN   NaN   NaN   NaN
# 4                   NewCapacity  MINCOA    2025   NaN   NaN   NaN   NaN   NaN
# ...                         ...     ...     ...   ...   ...   ...   ...   ...
# 10129  AnnualTechnologyEmission  MINNGS  EMIC02  2051   NaN   NaN   NaN   NaN
# 10130  AnnualTechnologyEmission  MINNGS  EMIC02  2052   NaN   NaN   NaN   NaN
# 10131  AnnualTechnologyEmission  MINNGS  EMIC02  2053   NaN   NaN   NaN   NaN
# 10132  AnnualTechnologyEmission  MINNGS  EMIC02  2054   NaN   NaN   NaN   NaN
# 10133  AnnualTechnologyEmission    MINN     NaN   NaN   NaN   NaN   NaN   NaN
#
# ...

# %%
python_converted.compare(access_converted)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-9b84bc8e24ff> in <module>
# ----> 1 python_converted.compare(access_converted)
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in compare(self, other, align_axis, keep_shape, keep_equal)
#    6213         keep_equal: bool = False,
#    6214     ) -> DataFrame:
# -> 6215         return super().compare(
#    6216             other=other,
#    6217             align_axis=align_axis,
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in compare(self, other, align_axis, keep_shape, keep_equal)
#    8656             )
#    8657
# -> 8658         mask = ~((self == other) | (self.isna() & other.isna()))
#    8659         keys = ["self", "other"]
#    8660
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/ops/common.py in new_method(self, other)
# ...
